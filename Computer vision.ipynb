# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Комментарий ревьюера 2</b>
#
# Спасибо за корректировки. Я оставила новые комментарии с цифрой 2. Надеюсь, тема была интересной. Проект я могу принять, поскольку вопросов больше нет.
#
#
# Хочу порекомендовать небольшой курс [MIT 6.S191: Introduction to Deep Learning](https://www.youtube.com/playlist?list=PLtBw6njQRU-rwp5__7C0oIVt26ZgjG9NI). Но там быстро и весьма поверхностно проходят по разным темам. У них на ютюбе множество записанных лекций на разные темы, в т.ч. и о компьютерных науках. Он интересен тем, что покрывает много тем и можно сразу понять, интересно тебе это или нет.  Желаю успехов на следующих спринтах! 😊
#
#
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px; ">
# <b> Комментарий ревьюера</b>
#
# Привет! Меня зовут Света, я буду проверять твой проект. Если не против, давай общаться на «ты». Если тебе такой стиль общения не нравится, напиши об этом, будем на «вы».
#
# Сразу хочу обратить внимание на цветовую разметку:
#
#
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# Зеленым с пометкой ✔️ отмечены отличные решения и идеи, которые можно и нужно использовать в будущем.
# </div>
#
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# Желтым с пометкой ⚠️ отмечено то, что можно или нужно оптимизировать, в зависимости от контекста.</div>
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# Красным с пометкой ❌ обозначены пропущенные пункты задания и ошибки, которые обязательно надо будет исправить, чтобы результаты были верные.</div>
#
# **Ответы на мои комментарии или доработки по моим рекомендациям попрошу выделить каким-нибудь цветом, кроме трех перечисленных.**
# Также я попрошу тебя **не менять и не передвигать мои комментарии**, чтобы при последующей проверке мне было проще ориентироваться.
#
# Кроме того, комментарии у меня обозначены как заголовки. Это сбивает содержание, но при последующей проверке я могу снять с них заголовок, если тебе так будет удобнее. При этом они удобны, поскольку ты сразу можешь перейти к ним.
#
# <hr>
#
# <font color= 'dodgerblue'>**По проекту:**</font>  отличная работа! Была построена и обучена модель, а результаты удовлетворяют требованиям ТЗ. Молодец!  У меня остались некоторые вопросы, я все написала в комментариях. Там же я оставила и рекомендации по улучшению проекта. Буду ждать работу на повторное ревью.
# </div>

# %% [markdown]
# # Определение возраста покупателей

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера  ❌</h2>
#
# Хотя основной целью проекта и является обучение модели, давай все же добавим постановку задачи: краткое ее описание и описание данных.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Добавила ниже
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️</h2>
#
# Это полезная привычка. Потом тебе будет проще вспоминать, что это за проект. К примеру, у меня на компьютере около сотни (если не больше) различных тетрадок с задачами, если не больше. От древних тетрадей с простыми задачами до важных проектов. Тут без комментариев ни за что не вспомнишь, о чем там речь шла и что вообще происходит в проекте :)
#
# </div>

# %% [markdown]
# # Описание проекта.
#
# Сетевой супермаркет «Хлеб-Соль» внедряет систему компьютерного зрения для обработки фотографий покупателей. Фотофиксация в прикассовой зоне поможет определять возраст клиентов, чтобы:
# 1. Анализировать покупки и предлагать товары, которые могут заинтересовать покупателей этой возрастной группы;
# 2. Контролировать добросовестность кассиров при продаже алкоголя.
# Необходимо постороить модель, которая по фотографии определит приблизительный возраст человека на основе набора фотографий людей с указанием возраста (предоставляется папка со всеми изображениями (/final_files) и CSV-файл labels.csv с двумя колонками: file_name и real_age.
#
# Задачи:
# 1. Исследовательский анализ набора фотографий.
# 2. Подготовка данные к обучению.
# 3. Обучение нейронной сети и рассчет её качества.

# %% [markdown]
# ## Исследовательский анализ данных

# %%
import pandas as pd
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator

labels = pd.read_csv('/datasets/faces/labels.csv')

print(labels.head())
print(labels.info())
print('Полных дубликатов:', labels.duplicated().sum())
print('Дубликатов по имени:', labels['file_name'].duplicated().sum())

labels['real_age'].hist(bins=50);
plt.xlabel('Возраст')
plt.ylabel('Количество объектов')
plt.title('Гистограмма распределения целевого признака "реальный возраст"')

labels.describe()
# Out:
#     file_name  real_age
# 0  000000.jpg         4
# 1  000001.jpg        18
# 2  000002.jpg        80
# 3  000003.jpg        50
# 4  000004.jpg        17
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7591 entries, 0 to 7590
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   file_name  7591 non-null   object
#  1   real_age   7591 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 118.7+ KB
# None
# Полных дубликатов: 0
# Дубликатов по имени: 0
#           real_age
# count  7591.000000
# mean     31.201159
# std      17.145060
# min       1.000000
# 25%      20.000000
# 50%      29.000000
# 75%      41.000000
# max     100.000000

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера ✔️</h2>
#
# Хорошо.
# </div><div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <h2> Комментарий ревьюера  ❌</h2>
#
# Графики нужно не только сразу комментировать, но и подписывать (оси + заголовок). Оформлять подписи следует на языке заказчика. Делать это можно с помощью указанных ниже команд, где plt это сокращение matplotlib.pyplot. Подправь, пожалуйста.
#
# </div>
#
# ```python
#
# plt.title('Заголовок')
# plt.xlabel('Подпись')
# plt.ylabel('Подпись')
# ```

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Поправила
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️</h2>
#
# Супер!
# </div>

# %% [markdown]
# В датафрейме 'labels' всего 7591 объект c харакеристиками - название файла и file_name(изображения содержаться в файлах формата jpg) и целевой признак real_age с возрастом людей, изображенных в файлах(целое число). Пропусков дубликатов в данных не обнаружено. Распределение по возрасту похоже на нормальное с всплеском около 0 лет и проседанием около 10 лет. Вершина смещена влево - к возрасту около 30 лет. Медиана приходится на возраст 29 лет.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера ✔️</h2>
#
#
#
# В целом, распределение вполне адекватное, хотя и не совсем равномерное, что может осложнить задачу для нашей модели.
#
# </div>

# %% [markdown]
# На примере анализа двух произвольных изображений можно сказать, что изображения имеют три цветовых канала и разную размерность.

# %%
fig = plt.figure(figsize=(10,10))
for i in range(10):
    image = Image.open('/datasets/faces/final_files/00000'+str(i)+'.jpg' )
    array = np.array(image)
    fig.add_subplot(2, 5, i+1)
    plt.imshow(array)
    plt.xticks([])
    plt.yticks([])
    plt.tight_layout()

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера ✔️</h2>
#
# Супер!
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера  ⚠️</h2>
#
# Две предыдущие ячейки можно тогда убрать. </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Убрала
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️</h2>
#
# Хорошо.
# </div>

# %% [markdown]
# Лица расположены практически вертикально и занимают большую часть изображения. Дополнительная обработка изображений не потребуется. На некоторых изображениях есть частички фона, что может затруднить анализ.

# %% [markdown]
# ## Обучение модели

# %% [markdown]
# Перенесите сюда код обучения модели и её результат вывода на экран.
#
#
# (Код в этом разделе запускается в отдельном GPU-тренажёре, поэтому оформлен не как ячейка с кодом, а как код в текстовой ячейке)

# %% [markdown]
# ```python
#
# # < скопируйте код сюда >
#
# ```
# ```python
#  # код
# from tensorflow.keras.models import Sequential
# import numpy as np
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
# from tensorflow.keras.applications.resnet import ResNet50
# import pandas as pd
#
# def load_train(path):
#     labels = pd.read_csv(path+'labels.csv')
#     train_datagen = ImageDataGenerator(rescale=1./255,
#        validation_split=0.25,
#        horizontal_flip=True,
#        rotation_range=40,
#        width_shift_range=20,
#        height_shift_range=20)
#
#
#     train_datagen_flow = train_datagen.flow_from_dataframe(dataframe=labels, directory= path+'/final_files/',
#        x_col='file_name',
#        y_col='real_age',
#        target_size=(224, 224),
#        batch_size=64,
#        class_mode='raw',
#        subset='training',
#        seed=45)
#
#     return train_datagen_flow
#
# def load_test(path):
#     labels = pd.read_csv(path+'labels.csv')
#     validation_datagen = ImageDataGenerator(
#     validation_split=0.25,
#     rescale=1./255)
#
#     val_datagen_flow = validation_datagen.flow_from_dataframe(dataframe=labels, directory= path+'/final_files/',
#        x_col='file_name',
#        y_col='real_age',
#        target_size=(224, 224),
#        batch_size=64,
#        class_mode='raw',
#        subset='validation',
#        seed=45)
#     return val_datagen_flow
#
#
#
# def create_model(input_shape):
#     optimizer = Adam(learning_rate=0.00001)
#     backbone = ResNet50(input_shape=(224, 224, 3),
#                     weights='/datasets/keras_models/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5',
#                     include_top=False)
#
#     model = Sequential()
#     model.add(backbone)
#     model.add(GlobalAveragePooling2D())
#     model.add(Dense(120, activation='relu'))
#     model.add(Dense(40, activation='relu'))
#     model.add(Dense(1, activation='relu'))
#     model.compile(optimizer=optimizer,
#               loss='mean_squared_error',
#               metrics=['mae'])
#
#
#     return model
#
#
# def train_model(model, train_data, test_data, batch_size=None, epochs=10,
#                steps_per_epoch=None, validation_steps=None):
#
#     model.fit(train_data,
#               validation_data=test_data,
#               batch_size=batch_size, epochs=epochs,
#               steps_per_epoch=steps_per_epoch,
#               validation_steps=validation_steps,
#               verbose=2)
#
#     return model

# %% [markdown]
# ```
#
# # < скопируйте результат вывода на экран сюда >
# # < длинные строки со скачиванием модели можно удалить >
#
#
#  # логи
#
# 2025-04-03 10:30:01.111725: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer.so.6
# 2025-04-03 10:30:01.114087: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer_plugin.so.6
# 2025-04-03 10:30:02.237450: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2025-04-03 10:30:02.244981: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:8b:00.0 name: Tesla V100-PCIE-32GB computeCapability: 7.0
# coreClock: 1.38GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2025-04-03 10:30:02.245035: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2025-04-03 10:30:02.245072: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2025-04-03 10:30:02.248146: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2025-04-03 10:30:02.248817: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2025-04-03 10:30:02.254278: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2025-04-03 10:30:02.256663: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2025-04-03 10:30:02.256750: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2025-04-03 10:30:02.259637: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1697] Adding visible gpu devices: 0
# Using TensorFlow backend.
# Found 5694 validated image filenames.
# Found 1897 validated image filenames.
# 2025-04-03 10:30:02.468418: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2025-04-03 10:30:02.476074: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 1999990000 Hz
# 2025-04-03 10:30:02.476751: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x4894140 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2025-04-03 10:30:02.476778: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2025-04-03 10:30:02.614302: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5ba8710 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-04-03 10:30:02.614344: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla V100-PCIE-32GB, Compute Capability 7.0
# 2025-04-03 10:30:02.615819: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:8b:00.0 name: Tesla V100-PCIE-32GB computeCapability: 7.0
# coreClock: 1.38GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2025-04-03 10:30:02.615886: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2025-04-03 10:30:02.615913: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2025-04-03 10:30:02.615954: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2025-04-03 10:30:02.615986: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2025-04-03 10:30:02.616034: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2025-04-03 10:30:02.616063: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2025-04-03 10:30:02.616084: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2025-04-03 10:30:02.618731: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1697] Adding visible gpu devices: 0
# 2025-04-03 10:30:02.618818: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2025-04-03 10:30:03.163066: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1096] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-04-03 10:30:03.163121: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102]      0
# 2025-04-03 10:30:03.163131: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] 0:   N
# 2025-04-03 10:30:03.165667: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2025-04-03 10:30:03.165713: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1241] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10240 MB memory) -> physical GPU (device: 0, name: Tesla V100-PCIE-32GB, pci bus id: 0000:8b:00.0, compute capability: 7.0)
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 89 steps, validate for 30 steps
# Epoch 1/10
# 2025-04-03 10:30:18.317124: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2025-04-03 10:30:19.362887: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2025-04-03 10:30:22.743839: W tensorflow/core/common_runtime/bfc_allocator.cc:243] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.55GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2025-04-03 10:30:22.743902: W tensorflow/core/common_runtime/bfc_allocator.cc:243] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.55GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 89/89 - 128s - loss: 1075.0070 - mae: 28.1737 - val_loss: 1095.6906 - val_mae: 28.5661
# Epoch 2/10
# 89/89 - 117s - loss: 428.9860 - mae: 16.7295 - val_loss: 1066.6629 - val_mae: 28.0754
# Epoch 3/10
# 89/89 - 110s - loss: 159.1090 - mae: 9.6469 - val_loss: 1062.4203 - val_mae: 28.0047
# Epoch 4/10
# 89/89 - 117s - loss: 107.7677 - mae: 7.9276 - val_loss: 1055.5565 - val_mae: 27.8954
# Epoch 5/10
# 89/89 - 117s - loss: 92.7019 - mae: 7.3920 - val_loss: 1029.8180 - val_mae: 27.5017
# Epoch 6/10
# 89/89 - 116s - loss: 83.0001 - mae: 7.0208 - val_loss: 892.2448 - val_mae: 25.1440
# Epoch 7/10
# 89/89 - 123s - loss: 76.6777 - mae: 6.7624 - val_loss: 421.9958 - val_mae: 15.4461
# Epoch 8/10
# 89/89 - 116s - loss: 69.5875 - mae: 6.3896 - val_loss: 185.7052 - val_mae: 9.9145
# Epoch 9/10
# Epoch 10/10
# 89/89 - 114s - loss: 63.6915 - mae: 6.1870 - val_loss: 127.5757 - val_mae: 8.4192
# 89/89 - 115s - loss: 61.6531 - mae: 6.0716 - val_loss: 102.3137 - val_mae: 7.6256
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 30/30 - 12s - loss: 102.3137 - mae: 7.6256

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера ✔️</h2>
#
# Да, аугментация лишней не будет.
#
# </div><div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <h2> Комментарий ревьюера  ❌</h2>
#
#
# - Не забывай про параметр `subset` при создании выборок. Проверить себя очень просто: в логах значения числа итераций на обучении и тесте совпадают. Иначе обучение и тест будут проходить на всей выборке.
#
#
#
#
# - Пожалуйста, оформи код и логи так, чтобы сохранилось форматирование. Ты можешь использовать Markdown ячейку, обернув код в такую конструкцию:
#
#
#     ```python
#
#     # код
#
#
#     # логи
#     ```
#
# Пример:
#
# </div>
#
#
# ```python
#
# import pandas as pd
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras.applications.resnet import ResNet50
#
#
#
# Epoch 1/20
# 356/356 - 53s - loss: 207.2425 - mae: 10.9765 - val_loss: 502.9258 - val_mae: 17.3614
# ```

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Убрала
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️</h2>
#
# Теперь все верно!
# </div>

# %% [markdown]
# ## Анализ обученной модели

# %% [markdown]
# В результате обучения модели, включающей архитектуру ResNet 50,  и применения ее к тестовым данным было  достигнуто значение «MAE» 7,6256, что меньше заданного значения 8 - значит результат был достигнут. Но это значит, что модель может ошибаться примерно на 7,6 лет при определении возраста.
# Модель может хуже распознавать лица детей и пожилых людей, так как их в выборке меньше, чем людей других возрастов.
# Было бы хорошо добавить больше изображения людей из данных возрстных групп - особенно подростков, тк это критично с точки зрения принятия реения о продажи им алкогольной продукции.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера ✔️</h2>
#
# Здорово, что не забываешь про общий вывод.
#
# </div>
#
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <h2> Комментарий ревьюера  ⚠️</h2>
#
# Конечно, результаты удовлетворяют условиям ТЗ. Однако если смотреть на них глазами кассира, погрешность довольно большая. Как думаешь, какими способами можно улучшить качество модели?
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Добавила последнее предлоение в выводе выше.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2  ✔️</h2>
#
#
# Что еще можно предпринять в подобной ситуации: не считая увеличения и корректировки самой выборки (иногда это и правда возможно), можно попробовать другие методы аугментации данных (кстати, вот интересная библиотека: [albumentations](https://github.com/albumentations-team/albumentations).), также можно рассмотреть добавление новых слоев и использование методов борьбы с переобучением (тот же dropout, к примеру). Что касается оптимизатора и шага градиента, то тут все хорошо.  Adam довольно универсален, хотя и уступает в некоторых вещах SGD и AdamW. Он хорош тем, что довольно быстро ищет минимум. Но если есть время на эксперименты и если это необходимо, то действительно можно попробовать разные методы оптимизации. При желании можно попробовать использовать [LearningRateScheduler](https://keras.io/api/callbacks/learning_rate_scheduler/), который меняет шаг в зависимости от стадии обучения. Правда, с малым числом эпох в этом не так много смысла :)
#
#
# Неплохой идеей будет использование других предобученных моделей.
#
# </div>

# %% [markdown]
# ## Чек-лист

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке исполнения
# - [x]  Исследовательский анализ данных выполнен
# - [x]  Результаты исследовательского анализа данных перенесены в финальную тетрадь
# - [x]  MAE модели не больше 8
# - [x]  Код обучения модели скопирован в финальную тетрадь
# - [x]  Результат вывода модели на экран перенесён в финальную тетрадь
# - [x]  По итогам обучения модели сделаны выводы
